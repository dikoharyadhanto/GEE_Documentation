# %% [markdown]
# <a href="https://colab.research.google.com/github/dikoharyadhanto/GEE_Documentation/blob/main/004_Drawing_Tools_to_Interact_GEE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=eA_VhBS6sfhRffKknWqRmyTlRzCsQWJ2W0E3xGHJyvI&tc=ak3DuXGeol8W6TL6Znumhw4RUZVlv5r0_4Wha_arOy4&cc=1-TNqXj2USeTsEGwVfDUdIR6t6x0dz4RNgFAaU9sW2w
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWih_XhBNd-8Yt1bq2kqNv_VNrfhz-zkjCsdfnd2z3ldFNnTdhmjod8
#
# Successfully saved authorization token.

# %%
# !pip install geemap

# %%
import geemap

Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# # **Add Earth Engine Dataset**

# %%
# Add Earth Engine Dataset
image = ee.Image('USGS/SRTMGL1_003')

# Set visualization parameters
vis_params = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']
}

# Add Earth Engine DEM to Map
Map.addLayer(image, vis_params, 'SRTM DEM')

states = ee.FeatureCollection("TIGER/2018/States")
Map.addLayer(states, {}, 'US States')

# %% [markdown]
# # **Draw Features**

# %% [markdown]
# ## **Check Draw Features**

# %%
Map.draw_features

# %%
Map.draw_last_feature

# %% [markdown]
# # **Select Data Layers Just Intersect with Draw Features**

# %% [markdown]
# Draw some polygon/line/points wherever you want first. Draw Features will be add into Layers Options

# %%
ROI = ee.FeatureCollection(Map.draw_features)
selected_states = states.filterBounds(ROI)
Map.addLayer(selected_states, {}, 'Selected States')

Map
# Out:
# Map(bottom=3457.0, center=[38.09998264736481, 249.76318359375003], controls=(WidgetControl(options=['position'…

# %%
clipped_image = image.clip(selected_states)
Map.addLayer(clipped_image, vis_params, 'Clipped Image')

Map
# Out:
# Map(bottom=1834.0, center=[41.11246878918088, 273.07617187500006], controls=(WidgetControl(options=['position'…
