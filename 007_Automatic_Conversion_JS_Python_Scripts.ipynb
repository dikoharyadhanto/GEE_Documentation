# %% [markdown]
# <a href="https://colab.research.google.com/github/dikoharyadhanto/GEE_Documentation/blob/main/007_Automatic_Conversion_JS_Python_Scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/08_ee_js_to_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
import ee

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=aglOTaOm9EH-lCTMeZ8gzB2sZKEc8EaguWgGz0dCIyY&tc=ry6uUZ7lXTnrjvrPDCXC_8MSMaMld2qtpD9GptcIgec&cc=qZNdyHhL51199QqZRCL3Gxak4zE_l_C2geAjdY4vaBo
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWgfcp3Yc_vZP20w-SgezzuOCVBpeOWOiblEaTSFgdYKSKubsAO4iUk
#
# Successfully saved authorization token.

# %%
# !pip install geemap
# Out:
# Collecting geemap
#   Downloading geemap-0.13.4-py2.py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 5.2 MB/s
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.5-py3-none-any.whl (30 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.33-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 43.3 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from geemap) (7.1.2)
# Requirement already satisfied: earthengine-api>=0.1.304 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.1.306)
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 8.3 MB/s
# Collecting ipytree
#   Downloading ipytree-0.2.1-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 47.4 MB/s
# Collecting jupyterlab>=3
#   Downloading jupyterlab-3.4.0-py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 38.3 MB/s
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting mapclassify>=2.4.0
#   Downloading mapclassify-2.4.3-py3-none-any.whl (38 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from geemap) (4.4.0)
# Collecting ipyleaflet>=0.14.0
#   Downloading ipyleaflet-0.16.0-py2.py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 54.0 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from geemap) (3.2.2)
# Collecting xyzservices
#   Downloading xyzservices-2022.4.0-py3-none-any.whl (36 kB)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from geemap) (1.3.5)
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.0-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.8 MB/s
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from geemap) (1.21.6)
# Collecting sankee
#   Downloading sankee-0.0.7.tar.gz (29 kB)
# Collecting python-box
#   Downloading python_box-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 39.0 MB/s
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-0.7.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 9.8 MB/s
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 67.9 MB/s
# Collecting folium>=0.11.0
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.2 MB/s
# Collecting ee-extra>=0.0.10
#   Downloading ee_extra-0.0.13.tar.gz (187 kB)
#      |████████████████████████████████| 187 kB 59.8 MB/s
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.0.4)
# Requirement already satisfied: httplib2shim in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.0.3)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.17.4)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.12.11)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.15.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.18.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.16.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (2.23.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (0.5.0)
# Collecting logzero>=1.5.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4>=4.9.0
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 62.6 MB/s
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.3.2.post1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.31.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (21.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.56.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (2022.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.2.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.0)
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.10.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (4.10.0)
# Collecting jupyter-server~=1.16
#   Downloading jupyter_server-1.17.0-py3-none-any.whl (342 kB)
#      |████████████████████████████████| 342 kB 51.7 MB/s
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.7-py3-none-any.whl (13 kB)
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.13.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.3 MB/s
# Collecting tornado>=4.0
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 48.7 MB/s
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (22.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.13.3)
# Collecting jupyter-client
#   Downloading jupyter_client-7.3.0-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 76.2 MB/s
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-6.5.0-py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 73.3 MB/s
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.8.0)
# Collecting websocket-client
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.9 MB/s
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (21.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (4.2.0)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.3.3)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.10.1)
# Collecting jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 57.9 MB/s
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.11.3)
# Collecting json5
#   Downloading json5-0.9.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (3.8.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from mapclassify>=2.4.0->geemap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from mapclassify>=2.4.0->geemap) (1.0.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from mapclassify>=2.4.0->geemap) (2.6.3)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (5.3.1)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.1.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (5.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.8)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (1.24.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.0)
# Collecting whitebox
#   Downloading whitebox-2.1.2-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.5 MB/s
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder->geemap) (7.1.2)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.0.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (0.4.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (1.4.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (1.7.1)
# Requirement already satisfied: plotly>=5.2.2 in /usr/local/lib/python3.7/dist-packages (from sankee->geemap) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.2.2->sankee->geemap) (8.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify>=2.4.0->geemap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify>=2.4.0->geemap) (3.1.0)
# Building wheels for collected packages: ee-extra, pycrs, sankee
#   Building wheel for ee-extra (setup.py) ... done
#   Created wheel for ee-extra: filename=ee_extra-0.0.13-py3-none-any.whl size=198407 sha256=ab275fa3a944378f92a91b7b4234e889d971b4ae373af25435d84922912530c7
#   Stored in directory: /root/.cache/pip/wheels/54/f2/bc/51930fbbffdd2ef1b5aac2e332c068e4913e56634f90efdef8
#   Building wheel for pycrs (setup.py) ... done
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32704 sha256=833cfaea0dfad07bb2ba800c994a4e78010d787cd72513ef15bcef65c8ae81ee
#   Stored in directory: /root/.cache/pip/wheels/3e/ce/32/1ec0aba6b9770681a423e82f0274c57d09ad2c20c2864901f9
#   Building wheel for sankee (setup.py) ... done
#   Created wheel for sankee: filename=sankee-0.0.7-py3-none-any.whl size=27639 sha256=cee68a8b0798bba496da7b42c323d8e1dbf7fd7bcff67b3e21498d2bc016e763
#   Stored in directory: /root/.cache/pip/wheels/13/28/83/5726f82a8cb0baf76169d99ee0595c420afedb9020e22bbd4b
# Successfully built ee-extra pycrs sankee
# Installing collected packages: tornado, jupyter-client, jinja2, beautifulsoup4, sniffio, nbconvert, websocket-client, anyio, jupyter-server, notebook-shim, json5, xyzservices, whitebox, traittypes, ratelim, nbclassic, logzero, jupyterlab-server, ipytree, ipyfilechooser, whiteboxgui, sankee, python-box, pyshp, pycrs, mapclassify, jupyterlab, ipyleaflet, ipyevents, geojson, geocoder, geeadd, folium, ffmpeg-python, ee-extra, colour, bqplot, geemap
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: folium
#     Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.12.1.post1 which is incompatible.
# Successfully installed anyio-3.5.0 beautifulsoup4-4.11.1 bqplot-0.12.33 colour-0.1.5 ee-extra-0.0.13 ffmpeg-python-0.2.0 folium-0.12.1.post1 geeadd-0.5.5 geemap-0.13.4 geocoder-1.38.1 geojson-2.5.0 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.16.0 ipytree-0.2.1 jinja2-3.1.2 json5-0.9.6 jupyter-client-7.3.0 jupyter-server-1.17.0 jupyterlab-3.4.0 jupyterlab-server-2.13.0 logzero-1.7.0 mapclassify-2.4.3 nbclassic-0.3.7 nbconvert-6.5.0 notebook-shim-0.1.0 pycrs-1.0.2 pyshp-2.3.0 python-box-6.0.2 ratelim-0.1.6 sankee-0.0.7 sniffio-1.2.0 tornado-6.1 traittypes-0.2.1 websocket-client-1.3.2 whitebox-2.1.2 whiteboxgui-0.7.0 xyzservices-2022.4.0

# %% [markdown]
# ## Automatic conversion from Earth Engine JavaScripts to Python scripts
#
# ### Install Earth Engine API and geemap
# Install the [Earth Engine Python API](https://developers.google.com/earth-engine/python_install) and [geemap](https://github.com/giswqs/geemap). The **geemap** Python package is built upon the [ipyleaflet](https://github.com/jupyter-widgets/ipyleaflet) and [folium](https://github.com/python-visualization/folium) packages and implements several methods for interacting with Earth Engine data layers, such as `Map.addLayer()`, `Map.setCenter()`, and `Map.centerObject()`.
# The following script checks if the geemap package has been installed. If not, it will install geemap, which automatically installs its [dependencies](https://github.com/giswqs/geemap#dependencies), including earthengine-api, folium, and ipyleaflet.
#
# **Important note**: A key difference between folium and ipyleaflet is that ipyleaflet is built upon ipywidgets and allows bidirectional communication between the front-end and the backend enabling the use of the map to capture user input, while folium is meant for displaying static data only ([source](https://blog.jupyter.org/interactive-gis-in-jupyter-with-ipyleaflet-52f9657fa7a)). Note that [Google Colab](https://colab.research.google.com/) currently does not support ipyleaflet ([source](https://github.com/googlecolab/colabtools/issues/60#issuecomment-596225619)). Therefore, if you are using geemap with Google Colab, you should use [`import geemap.foliumap`](https://github.com/giswqs/geemap/blob/master/geemap/foliumap.py). If you are using geemap with [binder](https://mybinder.org/) or a local Jupyter notebook server, you can use [`import geemap`](https://github.com/giswqs/geemap/blob/master/geemap/geemap.py), which provides more functionalities for capturing user input (e.g., mouse-clicking and moving).

# %%
import geemap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Convert Earth Engine JavaScripts to Python scripts

# %%
import os
from geemap.conversion import *

# Create a temporary working directory
#work_dir = os.path.join(os.path.expanduser('~'), 'geemap')
# Get Earth Engine JavaScript examples. There are five examples in the geemap package folder.
# Change js_dir to your own folder containing your Earth Engine JavaScripts,
# such as js_dir = '/path/to/your/js/folder'
js_dir = '/content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples'

# Convert all Earth Engine JavaScripts in a folder recursively to Python scripts.
js_to_python_dir(in_dir=js_dir, out_dir=js_dir, use_qgis=True)
print("Python scripts saved at: {}".format(js_dir))
# Out:
# Converting Earth Engine JavaScripts to Python scripts...
#
# Processing 1/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/QualityMosaic.js
# Processing 2/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/LinearRegression.js
# Processing 3/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/DecorrelationStretch.js
# Processing 4/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/SpectralUnmixing.js
# Processing 5/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationAndTemperature.js
# Processing 6/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/DoySeries.js
# Processing 7/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ColumnHistogram.js
# Processing 8/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageTimeSeriesByRegion.js
# Processing 9/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/SeasonalTemperatures.js
# Processing 10/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/TemperatureDisparity.js
# Processing 11/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageTimeSeries.js
# Processing 12/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageSpectra.js
# Processing 13/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationProfile.js
# Processing 14/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationHistogram.js
# Processing 15/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Sentinel2.js
# Processing 16/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat8TOAReflectanceQABand.js
# Processing 17/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Sentinel2CloudAndShadow.js
# Processing 18/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/MODISSurfaceReflectanceQABand.js
# Processing 19/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat8SurfaceReflectance.js
# Processing 20/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat457SurfaceReflectance.js
# Processing 21/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CodeEditor/MapCenterObject.js
# Processing 22/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CodeEditor/MapStyle.js
# Processing 23/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Sentinel1Composite.js
# Processing 24/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Landsat8HarmonicModeling.js
# Processing 25/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/EgyptClassification.js
# Processing 26/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/MODISHarmonicModeling.js
# Processing 27/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/NASANEXClimateModeling.js
# Processing 28/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Classification.js
# Processing 29/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/TerrainVisualization.js
# Processing 30/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/FromPolygons.js
# Processing 31/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/ReduceToImage.js
# Processing 32/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Join.js
# Processing 33/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/FromEarthEngineAsset.js
# Processing 34/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/ComputedAreaFilter.js
# Processing 35/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Buffer.js
# Processing 36/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Distance.js
# Processing 37/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ZeroCrossing.js
# Processing 38/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/NormalizedDifference.js
# Processing 39/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ModisQaBands.js
# Processing 40/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/PixelLonLat.js
# Processing 41/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ReduceRegion.js
# Processing 42/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Polynomial.js
# Processing 43/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/PixelArea.js
# Processing 44/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/LandcoverCleanup.js
# Processing 45/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/CenterPivotIrrigationDetector.js
# Processing 46/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Clamp.js
# Processing 47/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Hillshade.js
# Processing 48/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/FromName.js
# Processing 49/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/HoughTransform.js
# Processing 50/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/CannyEdgeDetector.js
# Processing 51/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ConnectedPixelCount.js
# Processing 52/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Expression.js
# Processing 53/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/HSVPanSharpening.js
# Processing 54/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/ClippedComposite.js
# Processing 55/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/FilteredComposite.js
# Processing 56/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/AnimatedThumbnail.js
# Processing 57/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/ExpressionMap.js
# Processing 58/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/SimpleCloudScore.js
# Processing 59/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/LinearFit.js
# Processing 60/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/LandsatSimpleComposite.js
# An error occurred when processing /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/LandsatSimpleComposite.js. The closing curly bracket could not be found in Line 24: function TOAComposite(collection,
# . Please reformat the function definition and make sure that both the opening and closing curly brackets apprear on the same line as the function keyword.
# Processing 61/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Primitive/DictionaryGet.js
# Processing 62/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_02.js
# Processing 63/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_04.js
# Processing 64/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_03.js
# Processing 65/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ZoomBox.js
# Processing 66/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/TwoChartInspector.js
# Processing 67/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/PopulationExplorer.js
# Processing 68/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/MobileFriendlyUI.js
# Processing 69/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/CollectionSlider.js
# Processing 70/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LinkedMaps.js
# Processing 71/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LayerFilters.js
# Processing 72/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/AsyncInspector.js
# Processing 73/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LandsatExplorer.js
# Processing 74/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ManualLegend.js
# Processing 75/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ForestChange.js
# Processing 76/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/SplitPanel.js
# Processing 77/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/OceanTimeseriesInvestigator.js
# Processing 78/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/MosaicEditor.js
# Processing 79/79: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/AirstripThumbnails.js
# Python scripts saved at: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples

# %% [markdown]
# ### Convert Earth Engine Python scripts to Jupyter Notebooks

# %%
# Convert all Earth Engine Python scripts in a folder recursively to Jupyter notebooks.
nb_template = get_nb_template()  # Get the notebook template from the package folder.
py_to_ipynb_dir(js_dir, nb_template)

# Execute all Jupyter notebooks in a folder recursively and save the output cells.
execute_notebook_dir(in_dir=js_dir)
# Out:
# Converting Earth Engine Python scripts to Jupyter notebooks ...
#
# Processing 1/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/QualityMosaic_qgis.py
#
# Processing 2/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/LinearRegression_qgis.py
#
# Processing 3/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/DecorrelationStretch_qgis.py
#
# Processing 4/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Arrays/SpectralUnmixing_qgis.py
#
# Processing 5/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationAndTemperature_qgis.py
#
# Processing 6/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/DoySeries_qgis.py
#
# Processing 7/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ColumnHistogram_qgis.py
#
# Processing 8/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageTimeSeriesByRegion_qgis.py
#
# Processing 9/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/SeasonalTemperatures_qgis.py
#
# Processing 10/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/TemperatureDisparity_qgis.py
#
# Processing 11/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageTimeSeries_qgis.py
#
# Processing 12/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ImageSpectra_qgis.py
#
# Processing 13/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationProfile_qgis.py
#
# Processing 14/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Charts/ElevationHistogram_qgis.py
#
# Processing 15/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Sentinel2_qgis.py
#
# Processing 16/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat8TOAReflectanceQABand_qgis.py
#
# Processing 17/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Sentinel2CloudAndShadow_qgis.py
#
# Processing 18/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/MODISSurfaceReflectanceQABand_qgis.py
#
# Processing 19/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat8SurfaceReflectance_qgis.py
#
# Processing 20/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CloudMasking/Landsat457SurfaceReflectance_qgis.py
#
# Processing 21/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CodeEditor/MapCenterObject_qgis.py
#
# Processing 22/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/CodeEditor/MapStyle_qgis.py
#
# Processing 23/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Sentinel1Composite_qgis.py
#
# Processing 24/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Landsat8HarmonicModeling_qgis.py
#
# Processing 25/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/EgyptClassification_qgis.py
#
# Processing 26/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/MODISHarmonicModeling_qgis.py
#
# Processing 27/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/NASANEXClimateModeling_qgis.py
#
# Processing 28/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/Classification_qgis.py
#
# Processing 29/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Demos/TerrainVisualization_qgis.py
#
# Processing 30/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/FromPolygons_qgis.py
#
# Processing 31/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/ReduceToImage_qgis.py
#
# Processing 32/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Join_qgis.py
#
# Processing 33/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/FromEarthEngineAsset_qgis.py
#
# Processing 34/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/ComputedAreaFilter_qgis.py
#
# Processing 35/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Buffer_qgis.py
#
# Processing 36/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/FeatureCollection/Distance_qgis.py
#
# Processing 37/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ZeroCrossing_qgis.py
#
# Processing 38/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/NormalizedDifference_qgis.py
#
# Processing 39/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ModisQaBands_qgis.py
#
# Processing 40/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/PixelLonLat_qgis.py
#
# Processing 41/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ReduceRegion_qgis.py
#
# Processing 42/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Polynomial_qgis.py
#
# Processing 43/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/PixelArea_qgis.py
#
# Processing 44/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/LandcoverCleanup_qgis.py
#
# Processing 45/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/CenterPivotIrrigationDetector_qgis.py
#
# Processing 46/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Clamp_qgis.py
#
# Processing 47/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Hillshade_qgis.py
#
# Processing 48/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/FromName_qgis.py
#
# Processing 49/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/HoughTransform_qgis.py
#
# Processing 50/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/CannyEdgeDetector_qgis.py
#
# Processing 51/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/ConnectedPixelCount_qgis.py
#
# Processing 52/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/Expression_qgis.py
#
# Processing 53/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Image/HSVPanSharpening_qgis.py
#
# Processing 54/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/ClippedComposite_qgis.py
#
# Processing 55/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/FilteredComposite_qgis.py
#
# Processing 56/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/AnimatedThumbnail_qgis.py
#
# Processing 57/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/ExpressionMap_qgis.py
#
# Processing 58/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/SimpleCloudScore_qgis.py
#
# Processing 59/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/ImageCollection/LinearFit_qgis.py
#
# Processing 60/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/Primitive/DictionaryGet_qgis.py
#
# Processing 61/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_02_qgis.py
#
# Processing 62/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_04_qgis.py
#
# Processing 63/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/tutorials/jrc_gsw/tutorial_global_surface_water_03_qgis.py
#
# Processing 64/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ZoomBox_qgis.py
#
# Processing 65/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/TwoChartInspector_qgis.py
#
# Processing 66/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/PopulationExplorer_qgis.py
#
# Processing 67/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/MobileFriendlyUI_qgis.py
#
# Processing 68/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/CollectionSlider_qgis.py
#
# Processing 69/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LinkedMaps_qgis.py
#
# Processing 70/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LayerFilters_qgis.py
#
# Processing 71/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/AsyncInspector_qgis.py
#
# Processing 72/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/LandsatExplorer_qgis.py
#
# Processing 73/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ManualLegend_qgis.py
#
# Processing 74/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/ForestChange_qgis.py
#
# Processing 75/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/SplitPanel_qgis.py
#
# Processing 76/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/OceanTimeseriesInvestigator_qgis.py
#
# Processing 77/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/MosaicEditor_qgis.py
#
# Processing 78/78: /content/drive/MyDrive/Colab Notebooks/GEE Scripts/js/examples/UserInterface/AirstripThumbnails_qgis.py
#
# Executing Earth Engine Jupyter notebooks ...
